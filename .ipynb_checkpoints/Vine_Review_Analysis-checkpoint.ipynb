# %%
import pandas as pd

# %%
# import data
df = pd.read_csv("vine_table.csv")
df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 0        RMDCHWD0Y5OZ9          3.0            0.0          1.0    N
# 1        RZSL0BALIYUNU          5.0            0.0          0.0    N
# 2        RIZR67JKUDBI0          3.0            0.0          1.0    N
# 3       R27HL570VNL85F          5.0            0.0          0.0    N
# 4       R34EBU9QDWJ1GD          5.0            0.0          0.0    N
# ...                ...          ...            ...          ...  ...
# 904760   R6MDTUK723YPY          4.0          143.0        148.0    N
# 904761  R10B4417NCK98O          5.0           24.0         24.0    N
# 904762  R3V2A0GUZ3JAQ4          4.0           27.0         29.0    N
# 904763  R1VYXC7FFG4LGH          4.0           46.0         49.0    N
# 904764  R2XJJXFZOM36V5          5.0           17.0         19.0    N
#
#        verified_purchase
# 0                      N
# 1                      Y
# 2                      Y
# 3                      Y
# ...

# %%
# filter by more than 20 total votes
lotta_votes_df = df.query('total_votes >= 20') 
lotta_votes_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 28      R2243Y3OD8U6KQ          5.0           47.0         61.0    N
# 85      R2TGT0CDTCAAHW          5.0           21.0         23.0    N
# 457      RX4D22YSXEF4P          1.0           37.0         38.0    N
# 1028    R3FL2NTLFUSPTQ          5.0           33.0         37.0    N
# 1039    R3QTP3YNZXAPPF          3.0           23.0         24.0    N
# ...                ...          ...            ...          ...  ...
# 904759  R2EJ952S3YK254          4.0           46.0         47.0    N
# 904760   R6MDTUK723YPY          4.0          143.0        148.0    N
# 904761  R10B4417NCK98O          5.0           24.0         24.0    N
# 904762  R3V2A0GUZ3JAQ4          4.0           27.0         29.0    N
# 904763  R1VYXC7FFG4LGH          4.0           46.0         49.0    N
#
#        verified_purchase
# 28                     N
# 85                     Y
# 457                    Y
# 1028                   N
# ...

# %%
# filter again by helpfulness
helpful_votes_df = lotta_votes_df.query('helpful_votes/total_votes >= 0.5')
helpful_votes_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 28      R2243Y3OD8U6KQ          5.0           47.0         61.0    N
# 85      R2TGT0CDTCAAHW          5.0           21.0         23.0    N
# 457      RX4D22YSXEF4P          1.0           37.0         38.0    N
# 1028    R3FL2NTLFUSPTQ          5.0           33.0         37.0    N
# 1039    R3QTP3YNZXAPPF          3.0           23.0         24.0    N
# ...                ...          ...            ...          ...  ...
# 904759  R2EJ952S3YK254          4.0           46.0         47.0    N
# 904760   R6MDTUK723YPY          4.0          143.0        148.0    N
# 904761  R10B4417NCK98O          5.0           24.0         24.0    N
# 904762  R3V2A0GUZ3JAQ4          4.0           27.0         29.0    N
# 904763  R1VYXC7FFG4LGH          4.0           46.0         49.0    N
#
#        verified_purchase
# 28                     N
# 85                     Y
# 457                    Y
# 1028                   N
# ...

# %%
# filter again for reviews left by vine = y
vine_yes_df = helpful_votes_df.query('vine == "Y"')
vine_yes_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 4229    R1R9RU7JW0MFR2          4.0           20.0         23.0    Y
# 9120    R19EFYNN3W8Q07          5.0           26.0         32.0    Y
# 34704   R34DJ1R8AEU0SG          5.0           29.0         35.0    Y
# 38510   R25P5CXK5L9RHF          5.0          146.0        161.0    Y
# 49330   R2E9VZB3I4LSN5          5.0           55.0         59.0    Y
# 73488    RKYLHZL7EPELX          4.0           19.0         25.0    Y
# 177563  R1U13EKGQD3ZE6          5.0           22.0         25.0    Y
# 190962   RYW05F1MUEF01          5.0           87.0        102.0    Y
# 227822  R2SW4NXNO7HZJ5          4.0           28.0         33.0    Y
# 237635  R2016NFLSUR97Y          2.0           26.0         37.0    Y
# 307453   RFCV9QXJ3D79X          3.0           20.0         22.0    Y
# 312863  R36779ZAY4ZT0Y          3.0           46.0         50.0    Y
# 316563  R13PPTBWWV10Q6          5.0           19.0         25.0    Y
# ...

# %%
# filter again for reviews left by vine = n
vine_no_df = helpful_votes_df.query('vine == "N"')
vine_no_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 28      R2243Y3OD8U6KQ          5.0           47.0         61.0    N
# 85      R2TGT0CDTCAAHW          5.0           21.0         23.0    N
# 457      RX4D22YSXEF4P          1.0           37.0         38.0    N
# 1028    R3FL2NTLFUSPTQ          5.0           33.0         37.0    N
# 1039    R3QTP3YNZXAPPF          3.0           23.0         24.0    N
# ...                ...          ...            ...          ...  ...
# 904759  R2EJ952S3YK254          4.0           46.0         47.0    N
# 904760   R6MDTUK723YPY          4.0          143.0        148.0    N
# 904761  R10B4417NCK98O          5.0           24.0         24.0    N
# 904762  R3V2A0GUZ3JAQ4          4.0           27.0         29.0    N
# 904763  R1VYXC7FFG4LGH          4.0           46.0         49.0    N
#
#        verified_purchase
# 28                     N
# 85                     Y
# 457                    Y
# 1028                   N
# ...

# %%
# find total number of reviews for vine=y & vine=n
total_reviews_yes = pd.Series(vine_yes_df['review_id']).count()
print(f'yes = {total_reviews_yes}')

total_reviews_no = pd.Series(vine_no_df['review_id']).count()
print(f'no = {total_reviews_no}')
# Out:
# yes = 60
# no = 14477

# %%
# find number of 5-star reviews for vine=y & vine=n
five_star_yes = vine_yes_df.query('star_rating == 5.0')
five_star_yes_num = pd.Series(five_star_yes['review_id']).count()
print(f'yes = {five_star_yes_num}')

five_star_no = vine_no_df.query('star_rating == 5.0')
five_star_no_num = pd.Series(five_star_no['review_id']).count()
print(f'no = {five_star_no_num}')
# Out:
# yes = 34
# no = 8212

# %%
# the percentage of 5-star reviews for vine=y(paid) & vine=n(unpaid)
yes_percentage = (five_star_yes_num / total_reviews_yes)
print(f'yes = {yes_percentage:.2%}')

no_percentage = (five_star_no_num / total_reviews_no)
print(f'no = {no_percentage:.2%}')
# Out:
# yes = 56.67%
# no = 56.72%
